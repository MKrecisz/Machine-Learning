# %%
import seaborn as sns #this is the plotting library I'll be using 
import pandas as pd #"as pd" means that we can use the abbreviation in commands
import matplotlib.pyplot as plt #we need Matplotlib for setting the labels in the Seaborn graphs

#loading 1st df
df1 = pd.read_csv('steps.csv', sep=";")
dfavg = df1.drop("id", axis = 1).mean(axis = 1)
df1["average"]=dfavg
df1.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    4364.0       NaN       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014  \
# ...

# %%
#loading 2nd df
df2 = pd.read_csv('survey.csv')
df2.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
#merging dfs
df = pd.merge(df1, df2, on = 'id') #'id' is the common identifier of two dfs
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014       average         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN  10205.521212     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN   5687.423313        Lille
# 2     8185.0     9630.0     8983.0  ...        NaN   8301.729730  Montpellier
# 3        NaN        NaN        NaN  ...        NaN   3633.200000         Lyon
# 4        NaN        NaN        NaN  ...        NaN   5312.129630  Montpellier
#
# ...

# %%
df.info() #Get information on the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 338 entries, id to weight
# dtypes: float64(331), int64(3), object(4)
# memory usage: 2.4+ MB

# %%
df['average'].value_counts() #Get all the values. This may be less useful when there are many values.
# Out:
# 1745.333333     1
# 5010.500000     1
# 10314.843750    1
# 6016.727273     1
# 5626.247967     1
#                ..
# 3941.918919     1
# 6281.930818     1
# 6582.890805     1
# 1449.400000     1
# 2592.000000     1
# Name: average, Length: 925, dtype: int64

# %%
df['average'] = df['average'].apply(pd.to_numeric, errors='coerce')
dfavg = df['average']

def above_25000(x):
    if(x > 25000): 
        return float('NaN')
    else: 
        return x
dfavg = dfavg.apply(above_25000)
mean_size = dfavg.mean()
median_size = dfavg.median()
avgvar = dfavg.var()
avgstd = dfavg.std()
print(f'The median is: {median_size}')
print(f'The mean is: {mean_size}')
print(f'The variance of average steps per user is: {avgvar}')
print(f'Standard diviation is: {avgstd}')
# Out:
# The median is: 6240.073033707865
# The mean is: 6703.996351176375
# The variance of average steps per user is: 8694607.658147227
# 2948.662011514244

# %%
#sns.histplot(df['average'].dropna(), kde=False) #Selecting the rating column. I need to drop the NA's for the plot
sns.distplot(dfavg, kde=False, vertical = False)
plt.title('Number of people per average amount of steps')
plt.xlabel('Number of steps')
plt.ylabel('Number of people')
plt.axvline(median_size, 0, 100, color='green', label='median') #This adds a vertical line at x-position median_size, from y = 0 to y = 100 
plt.axvline(mean_size, 0, 100, color='blue', label='mean') 
plt.legend() #This adds a legend. It works automatically because I've set the labels in the previous lines
plt.show()

# %%
sns.boxplot(dfavg)
plt.show()

# %% [markdown]
# We can see in those two graphs that the data makes it right skewed, so that means that the majority of people who contributed to gathering this data make averagely more than 6240.073033707865 steps daily.
#
#
# Verbal description of the distribution, including an investigation into its normality, skewness, outliers, etc
