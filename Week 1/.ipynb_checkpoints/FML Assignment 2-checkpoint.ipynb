# %%
import seaborn as sns #importing everything that's necessary
import pandas as pd 
import matplotlib.pyplot as plt

#loading 1st df
df1 = pd.read_csv('steps.csv', sep=";")
#alreqady preparing average steps
dfavg = df1.drop("id", axis = 1).mean(axis = 1)
df1["average"]=dfavg
#loading 2nd df
df2 = pd.read_csv('survey.csv')
#merging dfs
df = pd.merge(df1, df2, on = 'id') #'id' is the common identifier of two dfs
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014       average         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN  10205.521212     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN   5687.423313        Lille
# 2     8185.0     9630.0     8983.0  ...        NaN   8301.729730  Montpellier
# 3        NaN        NaN        NaN  ...        NaN   3633.200000         Lyon
# 4        NaN        NaN        NaN  ...        NaN   5312.129630  Montpellier
#
# ...

# %%
#cleaning data
def above_100000(x):
    if(x > 100000): 
        return float('NaN')
    else: 
        return x
    
def above_theheaviestmanonearth(x):
    if(x > 442): 
        return float('NaN')
    else: 
        return x
    
df['average'] = df['average'].apply(above_100000)
df['weight'] = df['weight'].apply(above_theheaviestmanonearth)

# %%
#pairplot just for a better outline of things
sns.pairplot(df[["average", "weight", "height" ]])

# %%
#correlation matrix
corr = df[["average", "weight", "height" ]].corr()
corr
# Out:
#           average    weight    height
# average  1.000000 -0.085936 -0.097515
# weight  -0.085936  1.000000  0.513935
# height  -0.097515  0.513935  1.000000

# %%
sns.scatterplot(data=df, x="average", y="weight")

# %%
sns.scatterplot(data=df, x="average", y="height")

# %%
dfselected = df[["average", "weight", "height" ]]
dfselected = dfselected.dropna(axis=0)
from scipy.stats.stats import pearsonr
print("Pearson's r for average steps and weight: ")
print(pearsonr(dfselected["average"], dfselected["weight"]))

print("Pearson's r for average steps and height: ")
print(pearsonr(dfselected["average"], dfselected["height"]))
# Out:
# Pearson's r for average steps and weight:
# (-0.08573768304459001, 0.009273340575367533)
# Pearson's r for average steps and height:
# (-0.09764070624792567, 0.0030302820511241657)

# %% [markdown]
# Pearson's r indicate that in both examples the correlation is not very significant. The strength of the association despite being stronger between average steps and height is also not very promising. Regarding the linearity, the first plot is not very linear and the second - showing a better distribution on the y axis - is.

# %%
sns.catplot(y="average", x="gender", kind="violin", data=df)
plt.show()

# %%
g = sns.catplot(x="gender", y="average",
                data=df, kind="bar",
                height=4, aspect=.7);

# %% [markdown]
# The bar graph indicate that Female do more average daily steps and the violin graph shows that more man do around 6000 daily steps than women.

# %%
sns.countplot(x =df["city"], hue =df["gender"])

# %%
pd.crosstab(df["city"],df["gender"], normalize="columns")*100
# Out:
# gender          Female       Male
# city
# Bordeaux     12.873563  14.777328
# Lille        58.160920  51.012146
# Lyon         15.172414  15.384615
# Montpellier  13.793103  18.825911

# %% [markdown]
# The bar plot shows that the most people (both male and female) that are in this dataset are from Lille. Regarding the ratio of genders in all the cities except Lille more men joined this research. In Lille despite there were more female, the ratio is a lot more even than in other cities.
